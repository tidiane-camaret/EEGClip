# %%
import numpy as np
import matplotlib.pyplot as plt
import mne
import pandas as pd
from braindecode.datasets import TUHAbnormal, BaseConcatDataset
from braindecode.preprocessing import (
    preprocess, Preprocessor, create_fixed_length_windows, create_windows_from_events, scale as multiply)
import torch
from braindecode.util import set_random_seeds

from braindecode.models import ShallowFBCSPNet, deep4
from skorch.callbacks import LRScheduler
from skorch.helper import predefined_split
from pytorch_lightning.callbacks.progress import TQDMProgressBar
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning import Trainer
from braindecode import EEGClassifier


mne.set_log_level('ERROR')  # avoid messages everytime a window is extracted

TUHAbnormal_PATH = '/home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2.0.0'
N_JOBS = 8  # specify the number of jobs for loading and windowing
N_SAMPLES = 1

tuh = TUHAbnormal(
    path=TUHAbnormal_PATH,
    #recording_ids=list(range(N_SAMPLES)),
    target_name=('report','pathological'),
    preload=False,
    add_physician_reports=True,
    n_jobs=N_JOBS, 
)

print("length of dataset : ", len(tuh))

# %%
df = tuh.description

# %%
df.to_csv("tuh_description.csv")

# %%
df[df.duplicated(["subject"],keep=False)]
# Out:
#                                                    path  year  month  day  \
# 2     /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2009      9    4
# 4     /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2009      9    9
# 7     /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2009      9   11
# 8     /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2009      9   15
# 10    /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2009      9   16
# ...                                                 ...   ...    ...  ...
# 2974  /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2013      9   25
# 2983  /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2013     10    4
# 2986  /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2013     10    5
# 2987  /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2013     10    7
# 2989  /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2013     10    7
#
#       subject  session  segment  age gender  \
# 2         929        3        2   39      F
# 4        5909        2        0   32      M
# 7        5928        1        0   70      F
# 8        4526        3        1   71      F
# 10       5931        1        1   69      M
# ...       ...      ...      ...  ...    ...
# 2974    10033        3        0   64      M
# 2983    10782        1        1   85      F
# 2986    10782        2        1   85      F
# 2987     6091        4        0   40      M
# 2989     7757        3        1   40      F
#
#                                                  report version  train  \
# 2     CLINICAL HISTORY:  Epilepsy, currently seizure...  v2.0.0   True
# 4     CLINICAL HISTORY: 32 year old male with episod...  v2.0.0   True
# 7     CLINICAL HISTORY:  71 year old woman with recu...  v2.0.0   True
# 8     \nCLINICAL HISTORY: 71 year old woman with epi...  v2.0.0  False
# 10    \n\nHISTORY: 69 year old male with psychiatric...  v2.0.0   True
# ...                                                 ...     ...    ...
# 2974  CLINICAL HISTORY:  A 64-year-old male status p...  v2.0.0   True
# 2983  CLINICAL HISTORY: 84-year-old woman with 3-ves...  v2.0.0  False
# 2986  CLINICAL HISTORY:  84-year-old woman with 3-ve...  v2.0.0  False
# 2987  CLINICAL 40-year-old man With LD, Childhood TB...  v2.0.0  False
# 2989  CLINICAL HISTORY:  A 38-year-old woman, with u...  v2.0.0   True
#
#       pathological
# 2            False
# 4            False
# 7             True
# 8             True
# 10            True
# ...            ...
# 2974          True
# 2983          True
# 2986          True
# 2987          True
# 2989         False
#
# [1107 rows x 13 columns]

# %%
categoy_pattern = r"^([A-Z\s]{2,}):{1}"
content_pattern = r":(.*)"
def remove_exccessive_white_space(string):
    replaces = re.sub(r'\s+', ' ', string)
    return replaces.strip()

# %%
df = tuh.description

# %%
def extract_categories(content):
    #content = b'\n'.join([line.strip() for line in content]).strip().decode("latin-1")
    categories = re.findall(categoy_pattern, content, re.MULTILINE)   
    assert len(categories) > 0, "no categories found"

    df_row = {}
    
    
    # go through all subsequent pairs of categories, extract text inbetween and assign it to start category
    for j in range(len(categories) - 1):
        start = categories[j]
        stop = categories[j + 1]
        match = re.findall(start + content_pattern + stop, content, re.DOTALL)
        assert len(match) == 1, "found more than one match!"
        # remove multiple spaces and newlines
        start = ' '.join(start.split())
        df_row.update({start: remove_exccessive_white_space(match[0])})
        
    # take all text that appears after last category and assign 
    match = re.findall(stop + content_pattern, content, re.DOTALL)
    assert len(match) == 1, "found more than one match!"
    # remove multiple spaces and newlines
    stop = ' '.join(stop.split())
    df_row.update({stop: remove_exccessive_white_space(match[0])})
    return df_row

# %%
categories = df['report'].apply(extract_categories)

# %%
df = pd.json_normalize(categories)
df = df.join(categories)

# %%
df
# Out:
#                                        CLINICAL HISTORY  \
# 0                                             Seizures.
# 1                           Schizophrenia, memory loss.
# 2                     Epilepsy, currently seizure-free.
# 3     Sixty-five-year-old woman with a previous eval...
# 4     32 year old male with episodes of bilateral ha...
# ...                                                 ...
# 2988  50-year-old woman with a history of light MCA ...
# 2989  A 38-year-old woman, with unclear epilepsy his...
# 2990  A 22-year-old with refractory epilepsy, 13 sei...
# 2991  A 55-year-old woman with restless legs syndrom...
# 2992  A 21-year-old female with multiple concussions...
#
#                                      MEDICATIONS  \
# 0                             Dilantin, Lipitor.
# 1     Geodon, simvastatin, benztropine, Norvasc.
# 2                              Lamictal, Keppra.
# 3                                       Norvasc.
# 4                                       Depakote
# ...                                          ...
# 2988                                         LEV
# 2989                 Tegretol, Depakote, others.
# 2990                                     Keppra.
# 2991    Keppra, Zoloft, Requip, insulin, others.
# 2992                Elavil, albuterol, Naprosyn.
#
#                                            INTRODUCTION  \
# 0     Digital video EEG is performed in the lab usin...
# 1     Digital video EEG is performed in the lab usin...
# 2     A 38-year-old right-handed woman with epilepsy...
# 3     Digital video EEG is performed in the lab usin...
# 4     Digital video EEG was performed in lab using s...
# ...                                                 ...
# 2988  Digital video EEG was performed in the lab usi...
# 2989  Digital video EEG is performed in the lab usin...
# 2990  Digital video EEG is performed in he lab using...
# 2991  Digital video EEG was performed in the lab usi...
# 2992  Digital video EEG was performed in the lab usi...
#
#                               DESCRIPTION OF THE RECORD  \
# 0     In wakefulness, there is a 9.8 Hz alpha rhythm...
# 1     In wakefulness, background EEG is well organiz...
# 2     Digital video EEG is performed using standard ...
# 3     The background EEG is appropriately organized ...
# 4     In wakefulness there is a 9.5 Hz posterior dom...
# ...                                                 ...
# 2988                                                NaN
# 2989  In wakefulness, there is a 10.5 Hz alpha rhyth...
# 2990  In wakefulness, there is a 10Hz alpha rhythm w...
# 2991  The background EEG demonstrates an awake patte...
# 2992  In wakefulness, there is a 10 Hz alpha rhythm ...
#
#                                              IMPRESSION  \
# 0                          Normal electroencephalogram.
# 1                                           Normal EEG.
# 2     EEG within normal limits but excessively drows...
# 3                            Normal EEG in wakefulness.
# 4                                            Normal EEG
# ...                                                 ...
# 2988  This Is an abnormal EEG due to: 1. A somewhat ...
# 2989  Normal electroencephalogram in wakefulness and...
# 2990  Abnormal EEG due to: 1. Right temporal focal s...
# 2991     This is a normal EEG primarily in wakefulness.
# 2992    Normal EEG in wakefulness and brief drowsiness.
#
#                                    CLINICAL CORRELATION  \
# 0     This is the third normal EEG for this individu...
# 1     This prolonged outpatient sleep deprived EEG w...
# 2     No epileptiform features are noted. The excess...
# 3                                                   NaN
# 4     No focal nor epileptiform features were identi...
# ...                                                 ...
# 2988  This EEG supports 8 complex epileptiform proce...
# 2989  No focal or epileptiform features were identif...
# 2990                                                NaN
# 2991  No focal or epileptiform features were identif...
# 2992  No focal or epileptiform features were identif...
#
#                                 CLINICAL INTERPRETATION      HR HISTORY  EKG  \
# 0                                                   NaN     NaN     NaN  NaN
# 1                                                   NaN     NaN     NaN  NaN
# 2                                                   NaN     NaN     NaN  NaN
# 3     No focal nor epileptiform features are identif...     NaN     NaN  NaN
# 4                                                   NaN  66 bpm     NaN  NaN
# ...                                                 ...     ...     ...  ...
# 2988                                                NaN     NaN     NaN  NaN
# 2989                                                NaN     NaN     NaN  NaN
# 2990                                                NaN     NaN     NaN  NaN
# 2991                                                NaN     NaN     NaN  NaN
# 2992                                                NaN     NaN     NaN  NaN
#
#       ... SEIZURES OR PUSHBUTTON EVENTS TECHNICAL CONSIDERATIONS FEATURES  \
# 0     ...                           NaN                      NaN      NaN
# 1     ...                           NaN                      NaN      NaN
# 2     ...                           NaN                      NaN      NaN
# 3     ...                           NaN                      NaN      NaN
# 4     ...                           NaN                      NaN      NaN
# ...   ...                           ...                      ...      ...
# 2988  ...                           NaN                      NaN      NaN
# 2989  ...                           NaN                      NaN      NaN
# 2990  ...                           NaN                      NaN      NaN
# 2991  ...                           NaN                      NaN      NaN
# 2992  ...                           NaN                      NaN      NaN
#
#      RECOMMENDATIONS TOTAL LENGTH OF THE RECORDING REASON DESCRIPTION RECORD  \
# 0                NaN                           NaN    NaN                NaN
# 1                NaN                           NaN    NaN                NaN
# 2                NaN                           NaN    NaN                NaN
# 3                NaN                           NaN    NaN                NaN
# 4                NaN                           NaN    NaN                NaN
# ...              ...                           ...    ...                ...
# 2988             NaN                           NaN    NaN                NaN
# 2989             NaN                           NaN    NaN                NaN
# 2990             NaN                           NaN    NaN                NaN
# 2991             NaN                           NaN    NaN                NaN
# 2992             NaN                           NaN    NaN                NaN
#
#      CLINICAL CORRELATE DATE OF STUDY  \
# 0                   NaN           NaN
# 1                   NaN           NaN
# 2                   NaN           NaN
# 3                   NaN           NaN
# 4                   NaN           NaN
# ...                 ...           ...
# 2988                NaN           NaN
# 2989                NaN           NaN
# 2990                NaN           NaN
# 2991                NaN           NaN
# 2992                NaN           NaN
#
#                                                  report
# 0     {'CLINICAL HISTORY': 'Seizures.', 'MEDICATIONS...
# 1     {'CLINICAL HISTORY': 'Schizophrenia, memory lo...
# 2     {'CLINICAL HISTORY': 'Epilepsy, currently seiz...
# 3     {'CLINICAL HISTORY': 'Sixty-five-year-old woma...
# 4     {'CLINICAL HISTORY': '32 year old male with ep...
# ...                                                 ...
# 2988  {'CLINICAL HISTORY': '50-year-old woman with a...
# 2989  {'CLINICAL HISTORY': 'A 38-year-old woman, wit...
# 2990  {'CLINICAL HISTORY': 'A 22-year-old with refra...
# 2991  {'CLINICAL HISTORY': 'A 55-year-old woman with...
# 2992  {'CLINICAL HISTORY': 'A 21-year-old female wit...
#
# [2993 rows x 126 columns]

# %%
def merge_columns(df, merge_to, merge_from, drop=True):
    # TODO: check that no data is overwritten by merging?
    assert merge_to in df.columns, "column {} not found in dataframe".format(merge_to)
    assert merge_from in df.columns, "column {} not found in dataframe".format(merge_from)
    df[merge_to][pd.isna(df[merge_to])] = df[merge_from][pd.isna(df[merge_to])]
    if drop:
        df = df.drop(merge_from, axis=1)
    return df
def merge_several_columns(df, merge_to, merge_from_several, drop=True):
    for column in merge_from_several:
        df = merge_columns(df, merge_to, column, drop=drop)

df = merge_several_columns(df, "CLINICAL CORRELATION", ["CORRELATION", "CLINICAL COURSE", "CLINICAL CORRELATIONS", "CLINICAL CORRELATE",
                                                        "CLINICAL INTERPRETATION", "CLINICAL CORR ELATION", "NOTE"])  # not sure about merging note

# %%
df = merge_several_columns(df, "CLINICAL HISTORY", ["HISTORY", "CLINICAL", "M CLINICAL HISTORY", "EEG REPORT CLINICAL HISTORY", 
                                                    "HOSPITAL COURSE", "BASELINE EEG CLINICAL HISTORY", "EEG NUMBER",
                                                    "ORIGINAL CLINICAL HISTORY"])

# %%
df = merge_several_columns(df, "DESCRIPTION OF THE RECORD", ["DESCRIPTION OF RECORD", "DESCRIPTION RECORD", "DESCRIPTION OF RECORDING", 
                                                             "DESCRIPTION OF THE RECORDING", "DESCRIPTION OF THE PROCEDURE", 
                                                             "DESCRIPTION OF BACKGROUND", "DESCRIPTION OF PROCEDURE", "OF THE RECORD",
                                                             "DESCRIPTION THE RECORD"])

# %%
df = merge_several_columns(df, "MEDICATIONS", ["MEDICATION", "CURRENT MEDICATIONS", "MEDICINES"])

# %%
df = merge_several_columns(df, "HEART RATE", ["HEAR RATE", "HR"])

# %%
df = merge_several_columns(df, "IMPRESSION", ["CLINICAL IMPRESSION"])

# %%
df = merge_several_columns(df, "FINDINGS", ["ABNORMAL FINDINGS"])

# %%
df = merge_several_columns(df, "EVENTS", ['SEIZURE EVENTS', 'SEIZURES OR EPISODES', 'EVENT', 'EPISODES', 'CLINICAL EVENTS',
                                          "EPISODES OR EVENTS", "EPISODES DURING THE RECORDING", "REFERRING FOR STUDY",
                                          "EVENTS OF PUSHBUTTON", "SEIZURES", "SEIZURE ACTIVITY"])

# %%
df = merge_several_columns(df, "TECHNICAL DIFFICULTIES", ["TECHNICAL PROBLEMS", "TECHNICAL DIFFICULTY", "CLINICAL DIFFICULTIES", "TECHNICAL DISCHARGES", 
                                                          "TECHNICAL NOTES", "TECHNICAL ISSUES", "TECHNIQUE DIFFICULTIES", "TECHNICAL CONSIDERATIONS",
                                                          "TECHNICAL QUALITY", "TECHNICAL", "ARTIFACTS"])

# %%
df = merge_several_columns(df, "CONDITION OF THE RECORDING", ["CONDITIONS OF THE RECORDING", "CONDITION OF RECORDING", 
                                                              "CONDITIONS OF RECORDING"])

# %%
df = merge_several_columns(df, "REASON FOR STUDY", ["REASON", "REASON FOR STUDIES", "REASON FOR EGG", "REASON FOR THE STUDY"])

# %%
df = merge_several_columns(df, "FINDINGS", ["DIAGNOSES", "DIAGNOSIS", "ABNORMAL DISCHARGES", "ABNORMAL DISCHARGE", 
                                            "EEG", "RECOMMENDATIONS"])  # not sure about merging recommendations

# %%
df = merge_several_columns(df, "PAST MEDICAL HISTORY", ["PAST HISTORY"])

# %%
df = merge_several_columns(df, "ACTIVATION PROCEDURES", ["ACTIVATION PROCEDURE", "ACTIVATING PROCEDURES", ])

# %%
df = merge_several_columns(df, "REASON FOR STUDY", ["REASON FOR EEG", "REASON FOR PROCEDURE"])

# %%
for drop_column in ["RECORDING TIMES", "RECORDING START TIME", "RECORDING END TIME", "RECORD FINISH TIME", "RECORD START TIME", 
                    "TOTAL LENGTH OF THE RECORDING", "RECORDING LENGTH", "TIME OF RECORDING", "LENGTH OF ELECTROENCEPHALOGRAM", 
                    "EEG LENGTH", "LENGTH OF EEG", "LENGTH OF PROCEDURE", "LENGTH OF THE RECORDING", "LENGTH OF THE EEG", 
                    "LENGTH OF RECORDING", "STUDY DATE", "DATE OF RECORDING", "EGG LENGTH", "TIME", "DURATION OF STUDY", 
                    "STUDY DURATION", "DATE OF THE RECORDING", "DATE OF STUDY", "DATES OF STUDY", "DT", "DD", "DENTAL PROBLEMS", 
                    "STAGES", "REASON FOR SEIZURES", "SEIZURES OR PUSHBUTTON EVENTS", "FEATURES", "INPATIENT ROOM", "EKG",
                    "DATE", "SLEEP"]:
    df = df.drop(drop_column, axis=1)

# %%
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [80], line 17
#      13 df = merge_several_columns(df, "CLINICAL CORRELATION", ["CORRELATION", "CLINICAL COURSE", "CLINICAL CORRELATIONS", "CLINICAL CORRELATE",
#      14                                                         "CLINICAL INTERPRETATION", "CLINICAL CORR ELATION", "NOTE"])  # not sure about merging note
#      16 # %%
# ---> 17 df = merge_several_columns(df, "CLINICAL HISTORY", ["HISTORY", "CLINICAL", "M CLINICAL HISTORY", "EEG REPORT CLINICAL HISTORY",
#      18                                                     "HOSPITAL COURSE", "BASELINE EEG CLINICAL HISTORY", "EEG NUMBER",
#      19                                                     "ORIGINAL CLINICAL HISTORY"])
#      21 # %%
#      22 df = merge_several_columns(df, "DESCRIPTION OF THE RECORD", ["DESCRIPTION OF RECORD", "DESCRIPTION RECORD", "DESCRIPTION OF RECORDING",
#      23                                                              "DESCRIPTION OF THE RECORDING", "DESCRIPTION OF THE PROCEDURE",
#      24                                                              "DESCRIPTION OF BACKGROUND", "DESCRIPTION OF PROCEDURE", "OF THE RECORD",
#      25                                                              "DESCRIPTION THE RECORD"])
#
# Cell In [80], line 11, in merge_several_columns(df, merge_to, merge_from_several, drop)
#       9 def merge_several_columns(df, merge_to, merge_from_several, drop=True):
#      10     for column in merge_from_several:
# ---> 11         df = merge_columns(df, merge_to, column, drop=drop)
#
# Cell In [80], line 3, in merge_columns(df, merge_to, merge_from, drop)
#       1 def merge_columns(df, merge_to, merge_from, drop=True):
#       2     # TODO: check that no data is overwritten by merging?
# ----> 3     assert merge_to in df.columns, "column {} not found in dataframe".format(merge_to)
#       4     assert merge_from in df.columns, "column {} not found in dataframe".format(merge_from)
#       5     df[merge_to][pd.isna(df[merge_to])] = df[merge_from][pd.isna(df[merge_to])]
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
df_row
# Out:
#                                                    path  year  month  day  \
# 0     /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2009      9    3
# 1     /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2009      9    3
# 2     /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2009      9    4
# 3     /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2009      9    4
# 4     /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2009      9    9
# ...                                                 ...   ...    ...  ...
# 2988  /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2013     10    7
# 2989  /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2013     10    7
# 2990  /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2013     10    7
# 2991  /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2013     10   10
# 2992  /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....  2013     11   22
#
#       subject  session  segment  age gender  \
# 0        4196        3        0   53      F
# 1        5864        1        0   30      M
# 2         929        3        2   39      F
# 3        5851        1        1   65      F
# 4        5909        2        0   32      M
# ...       ...      ...      ...  ...    ...
# 2988     6881        2        1   51      F
# 2989     7757        3        1   40      F
# 2990     9289        4        1   22      M
# 2991     3240        2        1   55      F
# 2992    10839        1        0   21      F
#
#                                                  report version  train  \
# 0     CLINICAL HISTORY:  Seizures.\nMEDICATIONS: Dil...  v2.0.0  False
# 1     CLINICAL HISTORY: Schizophrenia, memory loss.\...  v2.0.0  False
# 2     CLINICAL HISTORY:  Epilepsy, currently seizure...  v2.0.0   True
# 3     CLINICAL HISTORY:  Sixty-five-year-old woman w...  v2.0.0  False
# 4     CLINICAL HISTORY: 32 year old male with episod...  v2.0.0   True
# ...                                                 ...     ...    ...
# 2988  CLINICAL HISTORY: 50-year-old woman with a his...  v2.0.0   True
# 2989  CLINICAL HISTORY:  A 38-year-old woman, with u...  v2.0.0   True
# 2990  CLINICAL HISTORY: A 22-year-old with refractor...  v2.0.0   True
# 2991  CLINICAL HISTORY:  A 55-year-old woman with re...  v2.0.0   True
# 2992  CLINICAL HISTORY:  A 21-year-old female with m...  v2.0.0   True
#
#       pathological
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 2988          True
# 2989         False
# 2990          True
# 2991         False
# 2992         False
#
# [2993 rows x 13 columns]

# %%
reports = tuh.description["report"]

# %%
reports = reports.to_list()

# %%
reports

# %%
import re

pattern = r'([A-Z][A-Z\s]+): (.*)'
categories = []
for report in reports:
    matches = re.findall(pattern, report)
    categories.append(matches)

# %%
categories

# %%
category_names = []  
category_content = []
for report_cats in categories:
    names = [c[0] for c in report_cats]
    content = [c[1] for c in report_cats]
    category_names.extend(names)
    category_content.extend(content)

# %%
from collections import Counter
category_counts = Counter(category_names)

categories = list(category_counts.keys())
counts = list(category_counts.values())

frequent_categories = {cat:count for cat, count in category_counts.items() if count > 50}

# %%
frequent_categories
# Out:
# {'CLINICAL HISTORY': 2887,
#  'MEDICATIONS': 2869,
#  'INTRODUCTION': 2850,
#  'DESCRIPTION OF THE RECORD': 2864,
#  'IMPRESSION': 2999,
#  'CLINICAL CORRELATION': 2667,
#  'HR': 1370,
#  'HISTORY': 68,
#  'DESCRIPTION OF RECORD': 58,
#  'ABNORMAL DISCHARGES': 495,
#  'REASON FOR STUDY': 647,
#  'TECHNICAL DIFFICULTIES': 641,
#  'SEIZURES': 556,
#  'REASON FOR EEG': 63,
#  'DESCRIPTION OF THE RECORDING': 53,
#  'LENGTH OF RECORDING': 63,
#  'LENGTH OF THE RECORDING': 77,
#  'CONDITION OF THE RECORDING': 100,
#  'HEART RATE': 106}

# %%
category_content
# Out:
# [' Seizures.',
#  'Dilantin,  Lipitor.',
#  ' Digital video EEG is performed in the lab using standard 10-20 system of electrode placement with 1 channel EKG. Hyperventilation and photic stimulation are performed. This is an awake and asleep record.',
#  ' In wakefulness, there is a 9.8 Hz alpha rhythm with a small amount of low voltage frontal central beta activity. Hyperventilation produces a small amount of slowing. Photic stimulation does not activate the record.',
#  'Normal electroencephalogram.',
#  ' This is the third normal EEG for this individual with epilepsy. If appropriate, additional recording strategies may be helpful to characterize epileptiform activity.',
#  'Schizophrenia, memory loss.',
#  'Geodon, simvastatin, benztropine, Norvasc.',
#  'Digital video EEG is performed in the lab using standard 10-20',
#  'In wakefulness, background EEG is well organized',
#  'Normal EEG.',
#  'This prolonged outpatient sleep deprived EEG was',
#  ' Epilepsy, currently seizure-free.',
#  '  Lamictal, Keppra.',
#  ' A 38-year-old right-handed woman with epilepsy, current seizure\xad',
#  ' Digital video EEG is performed using standard',
#  ' EEG within normal limits but excessively drowsy patient.',
#  ' No epileptiform features are noted. The excessive drowsiness can be due to sleep deprivations, medications or a warm environment.',
#  ' Sixty-five-year-old woman with a previous evaluation many years ago for possible seizures, now with a spacey spell.',
#  ' Norvasc.',
#  ' Digital video EEG is performed in the lab using the standard 10-20 system of electrode placement with one channel EKG.  This is an awake record.',
#  ' The background EEG is appropriately organized for an adult of this age with a 10.5 Hz 60 microvolt posterior dominant rhythm.  Of note, although the overall record is normal, the later portions of the record are a bit synchronous.  A small amount of low voltage, frontocentral beta activity is observed.',
#  '  Normal EEG in wakefulness.',
#  'No focal nor epileptiform features are identified in this record.  Of note, however, the EEG is a bit more organized at the end and this may be compatible with postictal state.  Sleep was not achieved.',
#  '32 year old male with episodes of bilateral hand shaking and',
#  'Depakote',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'In wakefulness there is a 9.5 Hz posterior dominant',
#  '66 bpm',
#  'Normal EEG',
#  'No focal nor epileptiform features were identified in this',
#  '54 year old male with recurrent vertigo and fatigue.',
#  'Os-Cal, Nexium, Lexapro, Albuterol',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'In wakefulness, the background EEG is well',
#  'Normal EEG in wakefulness.',
#  'No epileptiform features are observed in this EEG. Normal',
#  '  49 year old left handed male with migraine headaches and visual scintillations.  Head trauma.',
#  ' Enalapril, Zocor, Glucosamine, ASA, Insulin',
#  '  Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.  Hyperventilation and photic simulation are preformed.',
#  '  In wakefulness, background EEG includes a well organized 10 hertz alpha rhythm with a small amount of low voltage, frontocentral beta activity. Drowsiness produces an increase in background theta. POSTS are observed in stage I sleep. Photic stimulation elicits scant driving. The patient drifts back into stage I sleep.',
#  '\t60 bpm',
#  '  Normal EEG.',
#  'No focal nor epileptiform features were identified.',
#  ' 71 year old woman with recurrent syncopal spells with a dazed look, hypertension, diabetes,  obesity, obstructive sleep apnea.',
#  ' Lisinopril, Heparin, Nifedipine, Lisinopril, Insulin, Protonix, ASA',
#  ' Digital video EEG was performed at bedside using standard 10-20 system of electrode placement with 1 channel EKG.  Photic stimulation is completed.',
#  'In maximal wakefulness, the background EEG is mildly slow with a posterior dominant rhythm of approximately 7.5 Hz. The patient is quite drowsy and rapidly drifts off into a drowsy pattern over steeper stages of sleep. Photic stimulation elicits an unilateral driving response, better elicited on the left compared to the right. In addition, the photic stimulation serves to alert the patient, at which point the left hemisphere seems to generate faster frequency better than the right.',
#  'Abnormal EEG due to:',
#  " The patient's hypersomnolence is more of a clinical issue. There are no epileptiform features noted. The focal features described above may be correlated with imaging.",
#  '71 year old woman with epilepsy, admitting with recurrent seizures and sedation.',
#  'Dilantin, Ativan, Keppra, Lamictal',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG. The patient is relatively somnolent. Photic simulation is performed.',
#  'The background EEG demonstrates a somewhat disorganized pattern. The patient is actually drowsy for much of the record and drifts in and out of stage II sleep. There is a bit of irregular slowing, asymmetric spindles in stage II sleep, more prominent on the left, and occasional right temporal sharp waves. Brief arousals are noted. Photic stimulation is performed while the patient is still somewhat sleepy, and there is primarily muscle artifact rather than driving.',
#  '66 bpm',
#  'Abnormal EEG due to:',
#  'These findings have been previously described. No seizures were recorded. The background slowing may represent a postictal state.',
#  '   38 year old right handed woman with migraine headaches, depression and a sharp pain in her head.',
#  'Xanax, Seroquel, Zolpidem, Nabumetone.',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG.  Hyperventilation and photic simulation are completed.',
#  ' In wakefulness background EEG is well-organized. There is a relatively fast alpha rhythm of 12 Hz with a small amount of low voltage, frontocentral beta. Hyperventilation produces an increased in amplitude of the background. This is followed by a drowsy and then stage I sleep with vertex waves and posts. Photic stimulation and hyperventilation are performed concurrently and do not active the record. In fact, the patient seems to drift into stage II sleep at the close of this study.',
#  '\t66 bpm',
#  'Normal EEG.',
#  'No focal nor epileptiform features are observed. Normal',
#  '69 year old male with psychiatric symptoms, boarding home resident and syncope versus seizure.',
#  'Clozapine, Metformin, Avandia, Diovan, Metformin, Amiodipine',
#  'Digital video EEG was performed in lab/bed using standard 10-20 system of electrode placement with 1 channel of EKG.  Hyperventilation and photic simulation are preformed.  This is an awake record. The EKG lead is not functioning.',
#  'The background EEG demonstrates rhythmic background slowing. There is a posterior dominant rhythm of 6-7 hertz, a scant amount of arrhythmic delta activity and generous beta.',
#  'N/A.',
#  ' Abnormal EEG due to:',
#  'These findings are nonspecific. They may be seen in a toxic or metabolic encephalopathy, postictal status or dementia. There were no epileptiform features.',
#  ' \t28 year old right handed woman with a possible TIA or stroke',
#  ' Aspirin, Amitriptyline, Motrin.',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG.  Photic simulation is performed. This is an awake and asleep record.',
#  ' In wakefulness, the background EEG is appropriately  organized with 10.5 Hz, 30 microvolt alpha rhythm and a small amount of wicket activity. Features of drowsiness include anterior spread of the alpha rhythm. Photic stimulation does not activate the record.',
#  'Normal EEG',
#  ' No focal nor epileptiform features are observed in the record. A  normal EEG does not exclude a diagnosis of seizure or stroke and correlation with imaging and history may be appropriate.',
#  '26 year old right handed female with daily migraines associated',
#  'Amitriptyline.',
#  'Digital video EEG was performed in lab using standard 1 0-20',
#  'In wakefulness background EEG is well organized',
#  '66 bpm',
#  'Normal EEG.',
#  'No epileptiform features were identified.',
#  'Zocor, Quinine, Cardura',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. Hyperventilation was not performed, but photic stimulation was completed.  This is an awake and a sleep record.',
#  ' In maximal wakefulness there is an 8.5 Hz alpha rhythm. Drowsiness is characterized by rhythmic background slowing. Photic stimulation was performed as the patient is drifting off to sleep and does not activate the record.',
#  '90 bpm',
#  ' Normal EEG.',
#  ' No focal nor epileptiform features were observed.',
#  '\t42 year old left-handed male with asthma and staring spells. MEDICATIONS: Advair.',
#  'Digital video EEG was performed in lab using standard  10-20',
#  '  In wakefulness there is a 9.5 Hz 40-mcv alpha rhythm which is symmetric and reactive to eye opening. There is a small amount of low voltage, frontocentral beta activity. Hyperventilation produces a small amount of slowing. Stage 1 and stage 2 sleep followed with vertex waves,  POSTS, and K complexes. Photic stimulation does not elicit a driving response.',
#  ' Normal EEG.',
#  ' 55 year old male with headache and syncope.',
#  ' N/A',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.  Hyperventilation and photic stimulation are performed. This is an awake and sleep record.',
#  ' In wakefulness there is a 10.5 Hz posterior dominant rhythm with a small amount of low voltage, frontal central beta activity. Drowsiness is characterized by increase in beta and decrease in alpha. Hyperventilation does not activate the record. Photic stimulation elicits brief driving.',
#  'Normal EEG.',
#  '  No focal nor epileptiform features are observed in this study.',
#  ' Albuterol, Prednisone,  Primacort.',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. Hyperventilation and photic stimulation are performed.',
#  ' In wakefulness, there is an 11 Hz 30 microvolt posterior dominant rhythm with a small amount of low voltage, frontal central beta activity. Photic stimulation elicits driving. Hyperventilation produces an increase in amplitude of the background. Drowsiness increases the synchronicity of the record.',
#  '\t60-70 bpm',
#  ' Normal EEG.',
#  '  No focal nor epileptiform features are observed.  Normal',
#  '  44 year old woman with HIV, epilepsy, bipolar disease. Seizures in April and July 2009 after patient stopped her Trileptal.',
#  ' Metoprolol, Reyataz, Combivir, Seroquel, ASA, Prazosin, Dapsone, Levemir',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.  Hyperventilation and photic simulation are preformed.',
#  ' The background EEG is low voltage, but there is',
#  '\t90 bpm',
#  '  EEG at the limits of normal.',
#  'There are no epileptiform features observed. If further characterization of her epilepsy is an important consideration, a repeat study capturing sleep is advised.',
#  '44 year old woman with epilepsy, seizures characterized by',
#  'Trileptal, Diovan, Albuterol.',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'In wakefulness, the background EEG is well',
#  '90 bpm',
#  'Abnormal EEG due to:',
#  ' 53 year old right handed male with head trauma in 1982, now losing track of time, depression,  anxiety, forgetfulness. Episodes of forgetfulness increasing in stress but none for the last month.',
#  'Metformin, Glyburide, Actoplus, Aceon',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.',
#  'In wakefulness the background EEG is well organized with 10 Hz 40 mcv posterior dominant rhythm. Occasional temporal wicket is observed. The patient transitions in and out of stage 2 sleep with vertex waves and spindles.  Hyperventilation produces an increase in amplitude of the background followed by drowsiness.  More extensive stage 2 sleep with vertex waves, K complexes, and spindles are observed later on in the record. Photic stimulation elicits a driving response at faster flash frequencies.',
#  ' Normal EEG.',
#  ' No focal nor epileptiform features are observed. The wicket activity described above is a normal variant.',
#  '80 year old male with focal seizures characterized by right arm jerking after right frontal stroke. Seizures were characterized by continuous right arm jerking in the context of a tiny right frontal stroke. Initial EEG demonstrated left frontal focal slowing, but no sharp waves.',
#  'Klonopin, Keppra, Lovenox, Hydralazine',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. The patient is very drowsy.',
#  'When the patient is maximally stimulated, there is a well-defined 9 Hz alpha rhythm. The patient drifts off to sleep with rhythmic background slowing and occasional bursts of shifting slowing. He is following asleep during stimulation, at which point vertex waves start to emerge. Scant driving response is noted.',
#  '60 bpm',
#  'EEG is within normal limits.',
#  'There are no epileptiform features observed today. There are no focal seizures. The patient seems to be drowsier than previous studies.',
#  '\t39 year old right handed male with daily headaches, evaluate for seizures.',
#  ' Cyclobenzaprine,  Zolpidem, Elavil, Cymbalta, Norvasc, Gabapentin',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG. This is an awake and primarily asleep EEG with photic stimulation but without hyperventilation.',
#  ' The majority of the record includes stage I and stage II sleep with vertex waves, K-complexes, spindles, and posts.   The patient is awakened for photic stimulation and has limited wakefulness.',
#  ' Normal EEG',
#  ' No epileptiform features are observed.  The primarily sleep EEG could be due to sleep deprivation or other disturbances like hypersomnolence, or even a sleep-deprived EEG. There are no epileptiform features.',
#  '30 year old male with fever and seizures and no other past medical history.',
#  'Versed,  Ativan, Phosphenytoin',
#  ' Digital video EEG was performed at bedside using standard 10-20 system of electrode placement with 1 channel EKG. Patient is intubated and is being evaluated for status epilepticus.',
#  ' This acute emergency room record demonstrates a markedly abnormal but dynamic pattern. As the tracing begins, the overall background is slow, even slightly discontinuous. There is an area in the right hemisphere of irregular epileptiform activity with sharp waves or spikes maximum at T6 P4 02 but with variability. There is even a spike that starts posteriorly and then demonstrates spread to T4 T6. Some of the discharges are followed by right frontally predominant rhythmic delta. As the recording continues, there is less',
#  ' Markedly abnormal EEG due to:',
#  ' This EEG supports an irritative process. In addition, there is focal slowing and bilateral background slowing. Correlation with clinical history is recommended.',
#  '  48 year old male with a history of tremor during sleep which began in July 2009.  The patient has a history of an MVA in June 2009 and hypertension.',
#  ' Valtrex, Nexium, Singulair, Metoprolol, Verapamil, Furosemide, Doxazosin, Flax seed oil, Omega fish oil.',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG.  Hyperventilation and photic simulation are preformed.',
#  ' In wakefulness, there is a low-voltage but well\xad defined 10 Hz alpha rhythm which is symmetric and reactive to eye opening.  Features of drowsiness include an increase of beta.  Hyperventilation produces background slowing.  Photic stimulation did not activate the record.',
#  ' EEG within normal limits.',
#  ' No epileptiform features are observed.  Normal EEG does not exclude a diagnosis of epilepsy, and a low-voltage pattern is a normal finding.',
#  '28 year old right handed male with seizures associated with hyperglycemia.',
#  'None',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG. Hyperventilation and photic simulation are performed. This is an awake and drowsy record.',
#  'In wakefulness, there is an 11 Hz, 50 microvolt posterior dominant rhythm with a small amount of low voltage, fronto-central beta activity. Brief drowsiness is characterized by anterior spread of the alpha rhythm. Hyperventilation produces an increase in amplitude of the background. Photic stimulation elicits a driving response.',
#  '66 bpm',
#  'Normal EEG.',
#  'No focal or epileptiform features are observed in this EEG. This is the second normal EEG for this individual.',
#  ' 37 year old woman with stroke, left-sided hemangioma.',
#  'Oxycodone,  Elavil, Diovan.',
#  'Digital video EEG was performed in lab using standard  10-20 system of electrode placement with 1 channel of EKG.  Hyperventilation and photic simulation are performed.  This is an awake and a sleep record.',
#  'In wakefulness there is posterior dominant rhythm. Drowsiness is characterized by an increase in background theta, followed by delta and then vertex waves and POSTS. Hyperventilation does produce background slowing. Photic stimulation elicits scant driving.',
#  ' EEG within normal limits.',
#  ' No focal nor epileptiform features were observed. Normal',
#  '42 year old right handed woman with migraine headaches, remote history of nocturnal seizures, and a previous MVA. Unclear historian today.',
#  'Megestive (?), Levetiracetam, Temazepam, Valium, Benadryl, Hydrocodone',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG. Hyperventilation and photic simulation are performed.',
#  'In wakefulness there is a 10 Hz 50 mcV posterior dominant rhythm with a generous amount of low voltage, frontocentral beta activity. Drowsiness is characterized by an increase in beta and an increase in theta as well as disappearance of the alpha rhythm. Hyperventilation does not activate the record but photic stimulation does elicit a driving response.',
#  '104 bpm',
#  'EEG within normal limits.',
#  "No epileptiform features were observed. The generous beta described above may be due to this patient's medications. The rapid heart rate could be due to anxiety but may be evaluated clinically.",
#  '81 year old right handed woman evaluated for seizure versus syncope. History of hypertension.',
#  'Simvastatin, Calcium, Lisinopril, Vit, B12',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'In wakefulness, the background EEG is',
#  '78 bpm',
#  'EEG within normal limits.',
#  'No focal nor epileptiform features are identified. The bad electrode should have been fixed during the study.',
#  '47 year old right handed male with a feeling of disequilibrium',
#  'None.',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'In wakefulness, the background EEG includes a 10',
#  '72 bpm',
#  'Normal EEG.',
#  'No focal nor epileptiform features are observed. The',
#  ' 54 year old woman with visual distortions lasting 45 minutes, scintillations and visual obscurations with left-sided headache.',
#  ' Aspirin,  Synthroid',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG.  Hyperventilation and photic stimulation are performed.',
#  ' In wakefulness the background EEG includes an',
#  ' Normal EEG.',
#  ' No focal nor epileptiform features are observed. Normal',
#  '67 year old female presented with syncope and toe ulceration.',
#  'Vancomycin.',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'The patient is drowsy throughout much of the',
#  '104 bpm',
#  'EEG within normal limits.',
#  'No focal nor epileptiform features were observed in the',
#  'Tegretol.',
#  '  Digital video EEG was performed at bedside using standard 10-20 system of electrode placement with 1 channel of EKG.  Hyperventilation and photic simulation are preformed.  The patient is awake and cooperative.',
#  ' In wakefulness, there is a well defined 9.3 hertz alpha rhythm with a small amount of low voltage fronto-central beta activity. Drowsiness is characterized by the appearance of rhythmic theta.',
#  '\t90 bpm',
#  ' Normal EEG.',
#  ' No epileptiform features are observed in this record. Normal EEG does not exclude a diagnosis of epilepsy. Of note, this record was',
#  '  59 year old right handed female with headaches and sharp occipital pain.',
#  'None',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG.  The patient is awake for most of the study, however, is in and out of drowsiness.',
#  ' The background EEG shows a 9.5 Hz alpha rhythm with 25 mV.  In addition, when drowsy the patient has 5 Hz temporal waves and some vertex waves.  Also noted is a rhythmic mid temporal theta of drowsiness (RMTD) which is a normal variant, entered during photic stimulation.  The patient is seen to have driving at 7 Hz.',
#  ' Normal EEG.',
#  'No focal nor epileptiform features are observed. A normal EEG does not exclude a diagnosis of epilepsy  Clinical evaluation of PVCs in sleep may be valuable.',
#  ' Neurontin, Metoprolol, Renagel, ASA, PhosLo',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. Hyperventilation was not performed, but photic simulation was completed.',
#  ' In wakefulness, there is a 9 hertz posterior dominant rhythm. Lambda waves are observed in the background. There is a generous amount of low voltage frontocentral beta activity and muscle artifact as the patient is not particularly cooperative. Features of drowsiness include an increase in background slowing, occasional vertex waves are observed. Photic stimulation elicits a subtle',
#  'EEG within normal limits.',
#  '  No focal nor epileptiform features are observed. Normal EEG does not exclude a diagnosis of epilepsy. Lambda waves are a normal phenomenon.',
#  '  37 year old woman requires neurologic clearance for foot surgery. Seizure free for the last 2 years.',
#  ' Dilantin.',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.  Hyperventilation and photic simulation are preformed.',
#  ' In wakefulness, background EEG includes a well organized 9.5 hertz 40 microvolts posterior dominant rhythm and a small amount of low voltage frontocentral beta. Hyperventilation produces an increase in amplitude of the background. Features of drowsiness include an increase in beta. Photic stimulation elicits scant driving.',
#  '  78 bpm',
#  ' Normal EEG',
#  'There are no focal nor epileptiform features noted in this record. If epilepsy is an important consideration, a repeat tracing capturing sleep may be of use.',
#  ' Tegretol',
#  'Digital video EEG was performed in lab using standard  10-20',
#  ' The patient begins the study in wakefulness and displays a 10 Hz alpha rhythm with 50 mV. There is higher amplitude on the left than',
#  ' Normal EEG.',
#  ' No epileptiform activity is noted. A normal EEG do not exclude diagnosis of epilepsy.',
#  '21 year old male with tonic-clonic seizures lasting 2 to 3',
#  'Depakote',
#  'Digital video EEG was performed in lab using standard 1 0-20',
#  'In wakefulness there is a low voltage 8.5 to 9Hz',
#  '48 bpm',
#  'Normal EEG',
#  'No epileptiform features were noted today. A normal EEG',
#  ' 71  year old right handed woman with cognitive problems and episodes of hypotension.',
#  ' Keppra, Insulin, Metformin, Prandin, Labetalol, Protonix, Zocor, Reglan',
#  ' Digital video EEG was performed in lab using standard  10-20 system of electrode placement with 1 channel EKG. Photic simulation was completed. This is an awake and asleep record.',
#  'In wakefulness, the background EEG is low voltage, but well organized with 9  Hz posterior dominant rhythm and a small amount of blow voltage fronto-central beta activity. Occasional mixed theta and delta is observed',
#  '\t78  bpm',
#  ' This EEG is just outside of the range of normal for a subject of this age due to somewhat more than expected temporal slowing from the right. A subject of this age is permitted a small amount of temporal slowing; however, there is a bit more observed from the right than the left and some of it  occurs with a bit more of a sustained beat of 4 Hz pattern.',
#  ' There are no epileptiform features noted. The temporal changes described above are nonspecific and can be seen in cerebrovascular disease.',
#  '89 year old right handed femaleá with and recurrent',
#  'None.',
#  'Digital video EEG was performed at bedside using standard 10-20',
#  'In wakefulness, the background EEG is low',
#  '90 bpm',
#  'EEG within normal limits for age.',
#  'No focal nor epileptiform features are observed in this',
#  ' Dilantin',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.  Hyperventilation and photic simulation are completed.',
#  ' In wakefulness, there is a 10  hertz,  30-50 microvolt posterior dominant rhythm with a small amount of low voltage, frontocentral beta',
#  '\t78 bpm',
#  ' Normal EEG.',
#  '  No epileptiform features are observed. Normal EEG does not exclude a diagnosis of epilepsy.',
#  '45 year old right handed woman with seizure versus',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'In wakefulness there was a 10 Hz alpha rhythm',
#  '78 bpm',
#  'Normal EEG.',
#  'No epileptiform features are observed. If epilepsy is a',
#  '\t67 year old woman with bipolar disease,  episode of loss of consciousness with confusion following the use of Wellbutrin. Syncope vs seizures.',
#  ' Zyprexa, Simvastatin',
#  ' In wakefulness background EEG is appropriately organized with 10 Hz, 50 microvolt posterior dominant rhythm and a small amount of',
#  '\t60 bpm',
#  ' Normal EEG',
#  'No epileptiform features were observed.  Normal electroencephalogram does not exclude a diagnosis of epilepsy. Of note, this is markedly improved compared to the previous study when she was admitted to the',
#  '40 year old woman with COPD, anxiety disorder with possible',
#  'Xanax, Albuterol,',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'The background EEG has a great deal of muscle',
#  'Normal EEG',
#  'If epilepsy is an important consideration, please consider',
#  ' 57 year old woman with epilepsy following intracerebral hemorrhage,',
#  ' Codeine, Trileptal, Crestor, ASA',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.  Photic stimulation is performed.  Technically this EEG is remarkable for a great deal of muscle and motion artifact.',
#  ' The background EEG is somewhat poorly organized. There is also a great degree of muscle artifact.  Superimposed upon this are bursts of rhythmic and arrhythmic delta activity in the right hemisphere.   The activity from the right frontal region tends to be rhythmic delta activity.  Underlying sharp waves are noted in this sharply contoured record and include T4/C4 and FP2. Features of drowsiness include additional bursts of paroxysmal high amplitude delta with an underlying right frontal sharp wave.\tPhotic stimulation elicits bilateral driving.',
#  '  84 bpm',
#  ' Abnormal EEG due to:',
#  ' These findings are similar to previous study with both a right hemispheric  process and background slowing and disorganization.  This is the first EEG in 1.5 years.  The patient had been relatively seizure free since February 2008.',
#  '\t24 year old woman with blackout spells following a cortisone shot for degenerative joint disease.',
#  'Tramadol, SOMA,',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.  Hyperventilation and photic simulation are performed.  This is an awake and asleep record.',
#  ' In wakefulness, there is a 10.5 Hz posterior dominant rhythm with alpha squeak. Features of drowsiness include slow rolling eye movements followed by anterior spread of the alpha rhythm. Hyperventilation produces an increase in amplitude of the background. Photic stimulation elicits bilateral driving.',
#  '  66 bpm',
#  ' Normal EEG in wakefulness and brief drowsiness.',
#  ' No focal nor epileptiform features were observed.',
#  ' 34 year old right handed woman with epilepsy since age 14',
#  ' Depakote',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG.  Hyperventilation and photic simulation are performed. This is an awake and asleep record.',
#  ' In wakefulness there is an 11 Hz alpha with a generous amount of low voltage, frontocentral beta activity. Stage I sleep includes an increase in beta followed by vertex waves. Photic stimulation elicits bilateral driving. Hyperventilation produces a small increase in the amplitude of the background.',
#  'Normal EEG',
#  ' No epileptiform features are seen.  In this individual with epilepsy, a more prolonged study capturing more extensive sleep may be helpful to identify epileptiform activity, and the beta may be due to anxiety.',
#  ' 28 year old woman with episodes of leg shaking and unresponsiveness.  Bipolar disease and depression.',
#  ' Depakote.',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG.  Hyperventilation and photic simulation are performed. The patient appears to be tense.',
#  ' The background EEG includes an 11 Hz alpha rhythm with muscle artifact and beta.   Hyperventilation does not activate the record. Photic stimulation elicits a driving response.',
#  '  60 bpm',
#  'EEG is within normal limits.',
#  'The beta and the muscle artifact can be observed in an individual receiving benzodiazepines or in an anxious person.  No epileptiform features were seen.  If epilepsy is an important consideration, a repeat study capturing deeper',
#  ' 38 year old right handed woman with syncope, intermittent dizziness, lightheadedness, loss of consciousness 5-7 times per week.',
#  'Naprosyn and Elavil.',
#  'Digital video-EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.  Hyperventilation and photic simulation are performed. This is an awake and asleep record.',
#  ' In wakefulness, the background EEG includes a well-developed 10.5 Hz alpha rhythm with a small amount of low voltage, frontocentral beta activity. Hyperventilation is performed early on in the record producing an increase in amplitude.  Beta activity is noted in stage I sleep.  Photic stimulation elicits scant driving.',
#  ' Normal EEG.',
#  '  No epileptiform features are observed. Normal EEG does not exclude a diagnosis of epilepsy. The bradycardia may be evaluated clinically.',
#  '62 year old right handed woman with episodes of loss of consciousness.',
#  'Prochlorperazine.',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. Hyperventilation and photic stimulation are performed. This is an awake and asleep record.',
#  'In wakefulness, there is a 10.5 Hz posterior dominant rhythm with a small amount of low voltage, frontocentral beta activity. Brief drowsiness is characterized by an increase in theta. Hyperventilation produces and increase in amplitude of the background. Photic stimulation elicits scant driving.',
#  '56 bpm',
#  'Normal EEG.',
#  'No focal nor epileptiform features are identified.',
#  '46 year old right handed male with seizure versus syncope versus hypoglycemic attack.',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. Hyperventilation and photic stimulation are performed. This is an awake and a sleep record.',
#  'In wakefulness, there is a 10 Hz, symmetric reactive alpha rhythm. The patient quickly becomes drowsy and when he does so rhythmic slowing of the alpha rhythm is noted. Hyperventilation also produces a small amount of background slowing. Photic stimulation elicits driving, but then the patient drifts off into sleep with theta in the background.',
#  '90 bpm',
#  'Normal EEG in wakefulness and drowsiness.',
#  'No epileptiform features were identified. The previous EEG was not noted.',
#  ' 52 year old right handed woman with a loss of consciousness this past Monday, hypersomnolence today prior to thyroidectomy. Ongoing confusion.',
#  'Ventolin, Albuterol.',
#  'Digital video EEG was performed at bedside using standard 10-20 system of electrode placement with 1 channel EKG.',
#  ' The majority of the record includes stage II  sleep with vertex, K complexes and spindles.  Little testing is performed to assess for cognitive testing.  The patient is stimulated and when she is awake, the background includes a well-defined, 9.5 Hz alpha rhythm.',
#  ' Normal EEG.',
#  ' This EEG demonstrates an excessively sleepy individual but normal awake through stage II sleep.  Morphology or wave forms are noted. Additional evaluation for the cause for her excessive drowsiness might be appropriate.',
#  '\t41   year old right handed male with recurrent panic attacks and syncopal episodes.',
#  ' Klonopin.',
#  '  Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1  channel EKG.  Hyperventilation and photic simulation are performed.   This is an awake and sleep record.',
#  '  In wakefulness, there is a 9.5 Hz posterior dominant rhythm. Features of drowsiness including increasing beta.  Brief stage II sleep is observed followed by spontaneous arousals.  Hyperventilation produces an increasing amplitude of the background.  Photic stimulation is performed as the patient is drifting off to sleep and does elicit scant driving.',
#  'Normal EEG in wakefulness and sleep.',
#  "  No epileptiform features are observed. The sleepiness and the generalized beta may be due to the patient's medications.",
#  '88 year old woman with frequent falling, rolled out of bed and',
#  'Simvastatin, verapamil, Keppra, Xalatan',
#  'Digital video EEG was performed at bedside using standard 10-20',
#  'In wakefulness, the background EEG is low',
#  '72 bpm and irregular',
#  'Normal EEG.',
#  'No epileptiform features are observed. Despite the',
#  '62 year old right handed male with prostate cancer found',
#  'Strovite, Lisinopril, Lipitor, Prandin, Omeprazole, ASA',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'In wakefulness there is a 60 mcV posterior',
#  '60 bpm',
#  'Normal EEG in wakefulness and drowsiness.',
#  'No focal nor epileptiform features are observed. A normal',
#  ' \t20 year old female with migraine headaches.',
#  ' Propofol',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.  Hyperventilation and photic stimulation are performed.  This is an awake and a sleep record.',
#  'In maximum wakefulness, there is a 10.5 Hz posterior dominant rhythm with posterior slow waves of youth.  Drowsiness is characterized by an increase in background slowing and a small degree of disorganization.  Hyperventilation produces an increase in amplitude. Photic stimulation elicits bilateral driving.',
#  'EEG within normal limits.',
#  '  No focal nor epileptiform features are observed.   Normal EEG does not exclude a diagnosis of epilepsy.',
#  '63 year old male, status post a complicated aneurysm surgery at age 55,',
#  'Dilantin, Namenda',
#  'Digital video EEG was performed in lab using standard 10-20 system of',
#  'The background EEG is somewhat slow and disorganized',
#  'N/A',
#  'Abnormal EEG due to:',
#  'This EEG supports a bi-hemispheric disturbance of cerebral',
#  ' 78 year old right handed female who has a history of strokes in',
#  ' Citalopram, Enalapril, Atenolol, Lovastatin, Aggrenox, Roxicet, hydrochlorothiazide, Glipizide, Oxycodone',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. Hyperventilation and photic simulation are performed.',
#  ' In wakefulness, the background EEG is low voltage, but there is 9.5 hertz symmetric reactive alpha rhythm. Features of drowsiness include an increase in beta. Rare, isolated right or left temporal theta/delta is noted in drowsiness.  Photic stimulation elicits bilateral driving.',
#  'EEG within normal limits in wakefulness and drowsiness.',
#  '  No epileptiform features were noted. A normal EEG does not exclude a diagnosis of epilepsy, but at present, the patient is symptom free off',
#  ' 47 year old right handed male with alcohol-related seizures x 2 years.',
#  '  None',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.  Hyperventilation and photic stimulation  are performed.',
#  ' In wakefulness, there is an 8.8 Hz alpha rhythm with a small amount of low voltage, frontocentral beta. Features of drowsiness include slow rolling eye movements. Brief epochs of stage 1 sleep are seen with vertex waves followed by arousals. Hyperventilation produces and increase in the amplitude of the background.  Photic stimulation does not elicit driving.',
#  '  60 bpm',
#  ' Normal EEG.',
#  " No focal nor epileptiform features are observed.  A normal EEG does not exclude a diagnosis of epilepsy. Patient's prior EEG in 2008 was also normal.",
#  ' 44 year old female presented with shaking spells associated with hypoglycemia, diabetes, hypertension, and heavy menstruation.',
#  'Humalog, Enalapril',
#  '  Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. Hyperventilation and photic stimulation are performed.',
#  '  In wakefulness, there is a well defined 10Hz alpha rhythm. There is a little bit  of head rocking artifact.  Photic stimulation elicits bilateral driving.Hyperventilation is performed with good effort producing an increase  in amplitude of the background. Drowsiness is characterized by hypersynchronous rhythm slowing.  Brief epochs of stage I sleep are observed.',
#  '\t90 bpm',
#  '  Normal EEG.',
#  '  No epileptiform features are observed.',
#  '74 year old female with new onset generalized tonoclonic seizure less than 45 seconds.',
#  'Ativan, Vancomycin, Valium.',
#  'Digital video EEG was performed at bedside using standard 10-20 system of electrode placement with 1 channel EKG. There was no photic or hyperventilation simulation used.',
#  'This is a diffusely slow EEG with an 8 Hz predominant rhythm. There are transient sharps originating from the right occipital region. It does occasionally involve the left occipital region. There is a posterior 3 to 6 Hz dominant focal slowing and sharp waves, sometimes seen With the sharp wave and sometimes independently.',
#  '72 bpm',
#  'Abnormal EEG due to:',
#  'This EEG supports a localized mechanism for epilepsy.',
#  '60 year old right handed woman with epilepsy, last seizure August 2009.',
#  'Carbatrol.',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG. Hyperventilation and photic simulation are completed.',
#  'In wakefulness there is a 10.5 Hz posterior dominant rhythm with a small amount of low-voltage, frontocentral beta. Hyperventilation is performed early in the record producing a small amount of theta. Photic stimulation elicits bilateral driving.',
#  '66 bpm',
#  'EEG within normal limits.',
#  'No focal nor epileptiform features were observed in this EEG. Normal EEG does not exclude a diagnosis of epilepsy. This is the 3rd EEG without epileptiform activity.',
#  '47 year old woman  with dizziness associated with movements of her head.',
#  ' None',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. The patient declined hyperventilation. Photic simulation was completed.',
#  ' In wakefulness there is a 9.5 Hz 50 microvolt posterior dominant rhythm with a small amount of low voltage, frontocentral beta activity.  Brief epochs of drowsiness are characterized by hypersynchronous rhythmic slowing. Sleep is not sustained.   Photic stimulation elicits scant driving.',
#  '\t84 bpm',
#  ' Normal EEG.',
#  ' No focal nor epileptiform features were observed.  Normal',
#  ' None',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.',
#  ' This is a very drowsy study. The patient drifts in and out of sleep during the entirety of the study. He does have a background alpha rhythm of 11 Hz. There is also the presence of POSTS, and slow rolling eye movements. During photic stimulation, there is a mild driving response until the patient falls asleep.  Hyperventilation creates an increased amplitude.',
#  ' Normal EEG.',
#  " There is no epileptiform activity. This was an otherwise normal EEG. Drowsiness may be related to sleep-deprived EEG, however the sleep is not sustained. This may be related to a sleep disorder. Normal EEG's do not exclude epilepsy. Based on clinical correlation, a repeat EEG may be warranted to find focal",
#  '\t80 year old woman with recent trauma status post fall due to unsteady gait. Had episode of eye twitching and myoclonic jerking of the arms and episodically of the legs. Indications to rule out seizure activity. Past medical history of A. fib, TIA, pacemaker.',
#  ' Cymbalta, Percocet,  ASA,Cymbalta, Clonazepam, Vicodin, Lovenox, Lotensin, Norvasc, Loratadine',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel  of EKG. Photic simulation was performed.',
#  "This is a well-organized symmetric EEG. There is alpha of 8-9 Hz throughout the record. The amplitude is mildly high for patient's age but this is nonspecific. There is some muscle artifact due to shaking episodes, however there are no EEG correlates to the shaking activity. Photic stimulation does not activate the record.",
#  '\t72 bpm and  regular.',
#  ' Normal EEG.',
#  '  There is no epileptiform activity. There are no focal features. This study is improved compared to prior EEG.',
#  '\t64 year old right handed female with bradycardia. Past medical history: Stroke, hypertension, seizures in October 2009.',
#  'Fentanyl, Atropine, Fludrocortisone,  Calcitriol, Levetiracetam, Alendronate, Insulin, Heparin,  Lorazepam, Clonidine, ASA, Zocor',
#  ' Digital video EEG was performed at bedside using standard 10-20 system of electrode placement with 1 channel of EKG.',
#  'There are episodes of shifting slowing bilaterally. First it slows on the right but later in the record she has bursts of delta on the left as well. There are first bursts of slowing theta as well as bilateral delta. The record is also',
#  'Moderately abnormal EEG due to:',
#  '  These findings are nonspecific and can represent either stigmata of ischemic cerebrovascular disease or a toxic metabolic encephalopathy.  A',
#  '46 year old man with a history of generalized tonoclonic seizures since childhood, the last seizure 2 weeks ago with right eye twitching and generalized shaking and postictal confusion.',
#  'Dilantin, Phenobarbital.',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement and 1 channel EKG. Hyperventilation and photic simulation were performed.',
#  'There are bursts of theta on the left but occasionally during drowsiness is seen bilaterally. He does reach an alpha rhythm of 10.5 Hz on the right. When he has bilateral bursts, the left is greater and more sustained than the right. This is accentuated during hyperventilation. Lateral eye movements are also seen. He has episodes of 3 to 4 Hz slowing, predominantly in the left temporal region. There are positive TIRDA predominantly in the left hemisphere in the temporal region and again is accentuated during hyperventilation. As the patient becomes sleepy during the exam, there are bilateral changes with alpha rhythm on the right but is not seen on the left. Also positive WICKETS. Photic stimulation does trigger driving of the record. Again, hyperventilation does increase amplitude and accentuates theta bilaterally, left greater than right.',
#  '72 bpm',
#  'Abnormal EEG due to:',
#  'There is no actual epileptiform activity. However, with the presence of sustained TIRDA, this is suggestive of a left focus in the temporal region and although TIRDA is not seizure activity, it is associated with a temporal lobe epilepsy. Further clinical correlation is recommended.',
#  '32 year old male with learning disability, seizure free since',
#  'Lamictal',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'In wakefulness, the background EEG is relatively',
#  '56 bpm',
#  'Abnormal EEG due to:',
#  'No epileptiform features were observed in this record',
#  '38 year old male with recurrent episodes of syncope for the past 2 years. This occurs twice a week where he feels lightheaded, dizzy and hot and awakens on the floor having hit his head.',
#  'Risperdal, Seroquel.',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. Hyperventilation and photic simulation are completed. This is an awake and asleep record.',
#  'In wakefulness, the background EEG is appropriately organized with a 1 0.5 Hz, 70 microvolt posterior dominant rhythm and a small amount of low voltage, frontal central beta activity. Drowsiness is characterized by occasional bursts of paroxysmal slowing following by vertex waves. Hyperventilation produces an increase in amplitude of the background. Photic stimulation elicits scant driving at intermediate flash frequencies.',
#  '72 bpm',
#  'Normal EEG in wakefulness and sleep.',
#  'No epileptiform features are identified. Normal EEG does not exclude a diagnosis of epilepsy. If seizures are an important concern, an outpatient ambulatory EEG may be helpful to characterize epileptiform activity.',
#  '  25 year old woman 8 months pregnancy with epilepsy since age',
#  ' None',
#  ' Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG.  Photic stimulation is performed. This an awake and a sleep record.',
#  ' The background EEG includes a 10 Hz 30 microvolt alpha rhythm.   Drowsiness is characterized by generous beta.  Beta spindles, vertex waves, and POSTS are identified in stage II sleep. Photic stimulation elicits bilateral driving.',
#  '\t96 bpm',
#  ' Normal EEG.',
#  "No focal nor epileptiform features are identified in this awake and asleep EEG.  After this the patient delivers her infant, additional EEG recording with activation techniques may be helpful to characterize epileptiform activity. Alternatively, comparison with previous EEG's may also be beneficial.  The generous beta activity could be associated with medications or anxiety.",
#  ' 62 year old right handed male with occipital headache, nausea, vomiting, confusion, and a past history of stroke.',
#  ' Dilantin, Neurontin.',
#  'Digital EEG was performed in lab using standard 10-20 system of electrode placement with 1  channel  of EKG.  Only photic stimulation could be performed. This is an awake and drowsy record.',
#  ' In wakefulness, the background EEG is moderately slow with background theta.  There are intermittent shifting asymmetries.  The waking record is less asymmetric and there is, at times, a 7 Hz posterior dominant rhythm, but',
#  'Abnormal  EEG due to:',
#  "  No epileptiform features are observed.  The findings described above may be correlated with this patient's imaging. Toxic metabolic encephalopathy, such as HHNK, can contribute to the generalized slowing, as well as the shifting slowing.",
#  '23 year old right handed male, with new onset tonic clonic',
#  'None',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'In wakefulness, there is a 10 Hz 30 microvolt',
#  '72 bpm',
#  'EEG within normal limits in wakefulness and sleep.',
#  'No epileptiform features were observed. Additional EEG',
# ...
#  '96 bpm',
#  'Abnormal EEG due to:',
#  'These findings on an adult of this age are nonspecific and can be seen in the context of a toxic or metabolic encephalopathy.',
#  '32 year old lady with questionable seizure activity, mostly',
#  'None.',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'During wakefulness background is well-organized',
#  '78bpm',
#  'Normal EEG.',
#  'Hyperventilation was not performed, Which is essential in',
#  '19 year.old male with a seizure 3 months ago.',
#  'Lamictal.',
#  'Digital video EEG was performed in lab standard 10-20',
#  'In wakefulness the EEG is acceptably',
#  '72 bpm',
#  'This EEG is within normal limits.',
#  'The EEG today demonstrates a normal variant which is',
#  '17 year old right handed female with recurrent tonic-clonic seizures characterized by blurry vision, generalized shaking, and unresponsiveness. Currently 12 weeks pregnant.',
#  'None',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. Patient is quite drowsy.',
#  'In wakefulness, there is a 10.5-Hz posterior dominant rhythm. Central mu rhythm is observed as is generous frontocentral beta. Vertex waves and spindles are observed in stage 1 sleep. Normal juvenile patterns of arousal with some hypersynchronous slowing are observed. Photic stimulation is performed while the patient is drifting in and out of sleep, but there is a generous photic driving response noted during photic stimulation.',
#  '72 bpm.',
#  'Normal record.',
#  'No focal nor epileptiform features are observed. Normal EEG does not exclude a diagnosis of epilepsy.',
#  '43 year old right handed female with a history of seizure disorder',
#  'Depakote.',
#  'Digital video EEG was performed in lab with standard 10-20 system',
#  'In wakefulness there is an 11.5 Hz alpha rhythm.Drowsiness is characterized by an increase in background beta with some central theta.',
#  '72 bpm',
#  'Normal EEG.',
#  'No epileptiform features are observed. Normal EEG does',
#  '37 year old right handed female with epilepsy since age 3 with',
#  'Depakote',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'In wakefulness, there is a 10 hertz alpha rhythm.',
#  '78 bpm',
#  'Normal EEG.',
#  'No focal or epileptiform features were observed. Normal',
#  'A 19-year-old woman, 26 weeks pregnant, with staring spells, episodes of poor responsiveness with shaking.',
#  'None.',
#  'Digital video EEG is performed at bedside using standard 10-20 system of electrode placement with one channel of EKG. This is an awake and asleep record in a very sleepy individual.',
#  'Much of this EEG includes abundant stage 2 sleep with vertex waves, K complexes, spindles, and POSTS. In maximal wakefulness the background EEG includes a 9.5-Hz alpha rhythm with head rocking artifact. The patient quickly drifts back to stage 2 sleep.',
#  'Normal EEG.',
#  'The hypersomnolence is the most remarkable feature about this record. These findings can be seen in the context of sleep deprivation or the use of medications. Additional evaluation for other causes of hypersomnolence may be considered. This record is a wonderful example of all the typical waveforms of stage 2 sleep.',
#  '62 year old right handed male with epilepsy, stroke and MVA.',
#  'Keppra, Diovan, Norvasc, Levetiracetam, Centrum, Amiodipine, Asa,',
#  'Digital video EEG was performed in lab using standard 10-20',
#  'In wakefulness, there is a 10.2 hertz posterior',
#  '60 bpm',
#  'EEG within normal limits.',
#  'No focal nor epileptiform features are observed. This is',
#  '31 year old female present for follow-up. Last seizure was 01/08/2010 x 2 with loc. Patient has history of intracerebellar CVA, headaches, eclampsia and renal insuff.',
#  'lasix, Lisinopril, Tegretol, Tylenol, ADA',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. Hyperventilation was not performed, but photic simulation was completed. This is an awake and asleep record.',
#  'In wakefulness, the background EEG is somewhat disorganized. There are some portions of maximal wakefulness where the overall pattern is reasonably well organized with a 9.5 hertz alpha rhythm. Other sections include bursts of frontally predominant rhythmic delta activity. In the transition to drowsiness, there is prominent arrhythmic delta activity and the overall background is more disorganized than one would except in a young adult. There is some shifting slowing and a single left temporal sharp wave is observed in this sharply contoured background. Stage II sleep includes vertex waves. Photic stimulation is performed while the patient is drifting in and out of stage II sleep and there is no significant driving response.',
#  '60 bpm',
#  'Abnormal EEG due to:',
#  'Only a single sharp wave was observed in this record. In this individual who is hospitalized on the 8th for complications of eclampsia, this is an improving pattern, but ongoing vigilance may be necessary.',
#  '53 year old left handed female with dementia, delirium, confusion.',
#  'Diovan, Metformin, Hydrocodone, ASA,',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. Hyperventilation and photic simulation are performed. This is an awake and asleep record.',
#  'In wakefulness, the overall background is relatively low voltage with a scant, 8 Hz alpha rhythm and generous beta. Hyperventilation is performed early in the record producing an increase in the amplitude of the background. Following hyperventilation as the patient drifts off to sleep, there is an increase in beta, rare bursts of temporal slowing followed by vertex waves and posts. Photic stimulation elicits bilateral driving.',
#  '72 bpm',
#  'EEG within normal limits.',
#  "No focal nor epileptiform features are observed in this record. This EEG is within the limits of normal. It is overall a lower voltage pattern. If epilepsy is an important consideration, a follow-up study may be considered. In addition, repeat studies may be helpful in monitoring the patient's cerebral pattern in the context of dementia/delirium.",
#  'Hepatitis C, status post cirrhosis and liver transplant, admitted for confusion and possible seizure.',
#  'Flagyl, vancomycin.',
#  'Digital video EEG is performed at bedside using standard 10-20 system of electrode placement with one channel of EKG. Hyperventilation and photic simulation are performed. The patient is intubated and poorly responsive.',
#  'The background EEG demonstrates a very low voltage, beta relatively featureless record with smaller amounts of delta. Stimulation of the patient produces muscle artifact.',
#  'Abnormal EEG due to replacement of normal background with primarily a beta frequency pattern with smaller amounts of delta.',
#  'No epileptiform features are noted. These features are nonspecific and support a diffuse disturbance of cerebral function, which may be due to many different causes. Careful review of the clinical history is important to make sure that the patient has not received benzodiazepine medication, which could produce the pattern described above.',
#  '69 year old female with dementia with mental status changes.',
#  'Insulin, Lovenox, Plavix, Metoprolol, ASA, Rifaximin',
#  'Digital video EEG was performed at bedside using standard 10-20 system of electrode placement with 1 channel of EKG. Hyperventilation and photic simulation are performed. The patient is poorly responsive.',
#  'The background EEG demonstrates a slow and disorganized pattern. The overall pattern is a mixture of delta and theta frequency activity. Stimulation of the patient produces an increase in muscle artifact.',
#  '90 bpm',
#  'Abnormal EEG due to:',
#  'These findings are nonspecific and can be seen in a diffuse disturbance of cerebral function. The prominent rhythmicity of the background particularly at the end when the theta frequency activity increases more toward a 6 Hz pattern which is compatible with a chronic dementing illness, but, again, the findings are nonspecific.',
#  '46 year old woman with epilepsy for the last 21 years, but seizure free for the last 2 years, history of a sleep disturbance.',
#  'Depakote.',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel of EKG. Hyperventilation and photic stimulation are performed. This is an awake and sleep record.',
#  'In wakefulness, the background EEG is relatively low voltage. There is a symmetric reactive 11 Hz alpha rhythm with a small amount of low voltage, frontal central beta activity. Mu rhythm is identified, as is some wicket activity. Features of drowsiness include an increase in beta. Photic stimulation elicits bilateral driving. During photic stimulation eye flutter is asymmetric, but a symmetric driving response is noted.',
#  '72 bpm',
#  'EEG is within normal limits.',
#  "There are no focal nor epileptiform features observed. There are multiple normal variants. The somewhat asymmetric eye flutter may suggest that electrode placement may have been suboptimal. If there are any questions a repeat study with specifically eye leads and a study all the way to stage 2 sleep can be helpful to characterize this individual's epilepsy.",
#  '80 year old right handed female in status post cardiac arrest on February 5, 2010. Past history of seizures.',
#  'Zocor, Vancomycin, Acyclovir, Keppra, ASA, Aricept, Bactrim, Moxifloxacin, Insulin, Lovenox, Dexamethasone, Ceftriaxone, Levothyroxine, dopamine, Norepinephrine',
#  'Digital video EEG was performed at bedside using standard 10-20 system of electrode placement with 1 channel of EKG. The patient had a seizure just prior to the EEG.',
#  'This EEG demonstrates some low voltage, subtlety discontinuous background. Some attenuation of about 3 seconds are interspersed with periods of low voltage, mixed theta delta. As the recording continues, the EEG is more continuous. There is some shifting asymmetries with more attenuation on the left compared to the right.',
#  'The patient is in the ICU at the bedside. She starts to have rhythmic mixed theta delta out of the left hemisphere, particularly the temporal region at 10:36:43. This gradually builds up, but at 10:36:55 she starts to have a burst of fast activity out of the right hemisphere. The bursts of fast activity builds up exquisitely, while the left hemisphere as a different frequency of activity with rhythmic delta. This is followed by more of a generalized pattern characteristic of more of a tonic clonic pattern, although behaviorally the patient is only observed to be having facial and head twitching. The activity starts to slow at 10:37:41. As it stops, it shuts off at 10:38 on the right, but continues on the left before terminating abruptly at 10:38:20. Postictally there is prominent background suppression as was noted in the early portions of the record.',
#  '162 bpm',
#  'Abnormal EEG due to:',
#  'This EEG supports a severe underlying encephalopathy, as well as very unusual mechanism for epilepsy. This seizure pattern is more typical of a chronic epilepsy than acute reactive seizure.',
#  '77 year old male with status post surgery for abdominal aortic aneurysm, now unresponsive. The time and date of his code are unknown.',
#  'Vasopressin, EPI, Amidone, Zocor, Protonix, Ceftriaxone, Versed, Morphine',
#  'Digital video EEG was performed at bedside using standard 10-20 system of electrode placement with 1 channel of EKG. Patient is intubated but not sedated.',
#  'The background EEG demonstrates a low voltage, continuous EEG. There is prominent background artifact from one of his bedside devices. In this relatively low voltage, somewhat suppressed background there is more delta, theta and even some alpha frequency activity in the frontal regions. Tactile stimulation produces some increase in theta.',
#  '60 bpm',
#  'Abnormal EEG due to:',
#  'These findings are nonspecific and can be seen in the diffuse disturbance of many different causes. No epileptiform features were identified.',
#  '77 year old male with past history of epilepsy, now with a lung mass and a syncopal episode.',
#  'Dilantin, Serax, ASA, Protonix, Lisinopril, Norvasc, Thiamine, Folic Acid',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG.',
#  'In wakefulness, there is a 9.5 Hz alpha rhythm. In the transition to drowsiness there is occasional theta identified independently in the left or right mid to anterior temporal region. Deeper stages of sleep are not identified. Photic stimulation elicits a subtle driving response.',
#  '72 bpm',
#  'Normal EEG.',
#  'The temporal changes described, left greater than right, in transition to sleep are considered normal for a subject of this age. There were no epileptiform features.',
#  '69 year old female with myelodysplasia admitted with fever, agitation. Seizures on the 9th.',
#  'Keppra, Lantus, Neurontin.',
#  'Digital video EEG was performed at bedside using standard 10-20 system of electrode placement with 1 channel of EKG. There is a fair amount of muscle artifact but the patient is relatively cooperative.',
#  'The background EEG demonstrates a somewhat slow and disorganized pattern with a 6 Hz posterior dominant rhythm and occasional posteriorly predominant delta. On one occasion there seems to be a right frontocentral sharp wave, but unfortunately muscle artifact makes it difficult to determine if similar waveforms might have been seen on the left. Features of drowsiness include increase in the posterior delta.',
#  '104 bpm',
#  'Abnormal EEG due to:',
#  "These findings have been previously described. In this individual with a relatively recent, right frontocentral seizure, there was little epileptiform activity identified today, however, the patient's muscle and movement artifact might obscure this.",
#  '54 year old woman admitted on 2/7/2010, after anoxic injury with complex epileptiform now intubated, comatose and no longer twitching.',
#  'Phenobarbital, Acyclovir, Pantoprazole, Mycamine, Heparin, CEFEPIME, Norepinephrine',
#  'Digital video EEG was performed at bedside using standard 10-20 system of electrode placement with 1 channel of EKG. The patient Is Intubated and unresponsive.',
#  'The background EEG demonstrates a discontinuous',
#  'N/A',
#  'Abnormal EEG due to:',
#  'These findings are similar to previous studies. These findings',
#  'A 72-year-old woman admitted on the 5th or the 9th with left MCA infarct. The patient began to have recurrent complex partial seizures on the night of the 11th which recurred.',
#  'Dilantin, ASA, Plavix, Lasix, Benadryl, Dilaudid',
#  'Digital video EEG was performed in lab using standard 10-20 system of electrode placement with 1 channel EKG. This EEG is recorded at multiple sections.',
#  'EEG characteristics of the seizures include rhythmic, repetitive, theta frequency, activity primarily from the left hemisphere including left frontotemporal. Some of this also involved delta. Most seizures seem to be about 2 minutes in duration and demonstrate frequent evolution. There is little in the way of postictal confusion, and the postictal background is actually quite symmetric with a definable posterior dominant rhythm. The degree of focal slowing in the left hemisphere is quite variable. Photic stimulation does not activate the record. During the later portions of the record, because the patient is having recurrent seizures, the technologist switches over the electrodes to collodion one-by-one during the continuous record. The seizures are characterized by head turning and confusion. The patient is aphasic but she is communicative before and after the seizures, and even during the seizures she seems to be making an attempt to communicate. Clinical features of the seizures include tremulousness of the hand. The right hand comes up to the mouth. She seems more confused.',
#  ...]

# %%
tuh.set_description(desc,overwrite=True)

# %%
tuh.description.path
# Out:
# 0    /home/jovyan/mne_data/TUH/tuh_eeg_abnormal/v2....
# Name: path, dtype: object
